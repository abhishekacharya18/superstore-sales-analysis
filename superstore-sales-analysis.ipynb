# %%
print("Hello Data Science")
# Out:
# Hello Data Science

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Setup Successful!")
# Out:
# Setup Successful!

# %%
df = pd.read_csv("C:\\Users\\abhis\\Downloads\\New folder\\Data Analysis\\Datasets\\Sample_ Superstore.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Row ID        9994 non-null   int64
#  1   Order ID      9994 non-null   str
#  2   Order Date    9994 non-null   str
#  3   Ship Date     9994 non-null   str
#  4   Ship Mode     9994 non-null   str
#  5   Customer ID   9994 non-null   str
#  6   Segment       9994 non-null   str
#  7   Country       9994 non-null   str
#  8   City          9994 non-null   str
#  9   State         9994 non-null   str
#  10  Region        9994 non-null   str
#  11  Product ID    9994 non-null   str
#  12  Category      9994 non-null   str
#  13  Sub-Category  9994 non-null   str
#  14  Product Name  9994 non-null   str
#  15  Sales         9994 non-null   float64
#  16  Quantity      9994 non-null   int64
#  17  Discount      9994 non-null   float64
#  18  Profit        9994 non-null   float64
# ...

# %%
df.shape
# Out:
# (9994, 19)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Segment', 'Country', 'City', 'State', 'Region',
#        'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Sales',
#        'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000    229.858001     3.789574     0.156203    28.656896
# std    2885.163629    623.245101     2.225110     0.206452   234.260108
# min       1.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.isnull().sum()
# Out:
# Row ID          0
# Order ID        0
# Order Date      0
# Ship Date       0
# Ship Mode       0
# Customer ID     0
# Segment         0
# Country         0
# City            0
# State           0
# Region          0
# Product ID      0
# Category        0
# Sub-Category    0
# Product Name    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"], format="mixed", dayfirst=True)

# %%
df["Year"] = df["Order Date"].dt.year

# %%
df["Sales"].sum()
# Out:
# np.float64(2297200.8603)

# %%
df["Profit"].mean()
# Out:
# np.float64(28.65689630778467)

# %%
df["Order ID"].nunique()
# Out:
# 5009

# %%
df.groupby("Category")["Sales"].sum()
# Out:
# Category
# Furniture          741999.7953
# Office Supplies    719047.0320
# Technology         836154.0330
# Name: Sales, dtype: float64

# %%
df.groupby("Region")["Profit"].sum()
# Out:
# Region
# Central     39706.3625
# East        91522.7800
# South       46749.4303
# West       108418.4489
# Name: Profit, dtype: float64

# %%
sns.barplot(x="Category", y="Sales", data=df)
plt.show()

# %%
sns.barplot(x="Region", y="Profit", data=df)
plt.show()

# %%
top_products = df.groupby("Product Name")["Sales"].sum().sort_values(ascending=False).head(10)
top_products
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#             Row ID     Sales  Quantity  Discount    Profit      Year
# Row ID    1.000000 -0.001359 -0.004016  0.013480  0.012497  0.015430
# Sales    -0.001359  1.000000  0.200795 -0.028190  0.479064 -0.009679
# Quantity -0.004016  0.200795  1.000000  0.008623  0.066253 -0.005810
# Discount  0.013480 -0.028190  0.008623  1.000000 -0.219487 -0.002662
# Profit    0.012497  0.479064  0.066253 -0.219487  1.000000  0.004670
# Year      0.015430 -0.009679 -0.005810 -0.002662  0.004670  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()

# %%
Conclusion

Technology category records the highest total sales. The category leads revenue contribution in the dataset.

West region shows the highest total profit. The region performs better than other regions in profit generation.

Some products generate negative profit. These products create financial loss despite recorded sales.

Higher discount levels reduce profit margins. Increased discount rates associate with lower profit values.
